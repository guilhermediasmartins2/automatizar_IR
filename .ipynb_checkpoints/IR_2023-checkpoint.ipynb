# %%
import pandas as pd
import pyautogui
import time
import pyperclip

# %% [markdown]
# # Funções

# %%
def encontrar_imagem(imagem):
    while not pyautogui.locateOnScreen(imagem, confidence=0.8):
        encontrou = pyautogui.locateOnScreen(imagem, confidence=0.8)
        print(encontrou)
        time.sleep(1)
    return pyautogui.locateOnScreen(imagem, confidence=0.8)
time.sleep(1)

def converter_num_Brasil(num):
    return num.replace(",", "_").replace(".", ",").replace("_", ".")

def copiar_colar(texto):
    pyperclip.copy(texto)
    pyautogui.hotkey("ctrl", "v")
    return texto

# %% [markdown]
# # Tratando planilha Declaração Pessoal

# %%
ano = 2022
#Importando e tratando a planilha de Declaração

rend_isentos = pd.read_excel(r"C:\Users\guilh\GitHub\automatizar_IR\Declaração_Pessoal.xlsx", sheet_name = [1])[1]
rend_trib_excl = pd.read_excel(r"C:\Users\guilh\GitHub\automatizar_IR\Declaração_Pessoal.xlsx", sheet_name = [2])[2]
pagamentos_efetudos = pd.read_excel(r"C:\Users\guilh\GitHub\automatizar_IR\Declaração_Pessoal.xlsx", sheet_name = [3])[3]
bens_direitos = pd.read_excel(r"C:\Users\guilh\GitHub\automatizar_IR\Declaração_Pessoal.xlsx", sheet_name = [4])[4]
base_ticket = pd.read_excel(r"C:\Users\guilh\GitHub\automatizar_IR\Declaração_Pessoal.xlsx", sheet_name = [5])[5]

#Localizando o hifem e criando uma coluna para apenas as letras do código
for linha in base_ticket.index:
    posicao_1 = base_ticket.loc[linha, "Código de Negociação"].find("1")
    if posicao_1 != -1:
        if posicao_1 >= 1 and base_ticket.loc[linha, "Código de Negociação"][posicao_1] == "1":
            base_ticket.loc[linha, "inicio_ticket"] = base_ticket.loc[linha, "Código de Negociação"][:posicao_1]
        else:
            base_ticket.loc[linha, "inicio_ticket"] = base_ticket.loc[linha, "Código de Negociação"]
    else:
        base_ticket.loc[linha, "inicio_ticket"] = base_ticket.loc[linha, "Código de Negociação"][:-1]

display(base_ticket)
# Out:
#    Código de Negociação                                       Razão Social  \
# 0                 BBAS3                                    BANCO DO BRASIL
# 1                 WEGE3                                            WEG S.A
# 2                 FLRY3                                         FLEURY S.A
# 3                 ABEV3                                          AMBEV S.A
# 4                SAPR11                        CIA DE SANEAMENTO DO PARANA
# 5                TAEE11                  TRANSMIS. ALIANCA ENERG. ELETRICA
# 6                 PSSA3                                   PORTO SEGURO S.A
# 7                 MGLU3                                 MAGAZINE LUIZA S.A
# 8                 LREN3                                   LOJAS RENNER S.A
# 9                 ITSA4                                         ITAUSA S.A
# 10                ITSA3                                         ITAUSA S.A
# 11                EGIE3                           ENGIE BRASIL ENERGIA S.A
# 12                BBSE3                         BANCO DO BRASIL SEGURIDADE
# 13                  AMT                         AMERICAN TOWER CORPORATION
# 14                  DLR                           DIGITAL REALTY TRUST INC
# 15                  ESS                           ESSEX PROPERTY TRUST INC
# 16                  NNN                     NATIONAL RETAIL PROPERTIES INC
# 17                  PLD                                       PROLOGIS INC
# 18                    O                          REALTY INCOME CORPORATION
# 19                B3SA3                          B3 AS BRASIL BOLSA BALCAO
# 20                ODPV3                                     ODONTOPREV S.A
# 21               AURA33                                  AURA MINERALS INC
# 22               XPLG11                            XP LOG FDO INV IMOB FII
# 23               VILG11                  VINCI LOGISTICA FDO INV IMOB FII
# 24               VINO11                         VINCI OFFICES FDO INV IMOB
# 25               VISC11         VINCI SHOPPING CENTERS FDO INVEST IMOB FII
# 26               ALZR11                    ALIANZA TRUST RENDA IMOBILIARIA
# 27               IRDM11                    IRIDIUM RECEBIVEIS IMOBILIARIOS
# 28               MXRF11                                     FII MAXI RENDA
# 29               HGRU11                              CSHG RENDA URBANA FII
# 30               VRTA11                      FATOR VERITA FDO INV IMOB FII
# 31               BCRI11  BANESTES RECEBIVEIS IMOBILIARIOS FDO INV IMOB FII
# 32               BTLG11                             BTG PACTUAL LOGISTICA
# 33               KNRI11                        FII KINEA RENDA IMOBILIARIA
# 34                  QQQ                          INVESCO QQQ TR UNIT SER 1
# 35                 NOBL             S&P 500 DIVIDEND ARISTOCRATS PROSHARES
# 36                  IAU                           GOLD TRUST (ETF) ISHARES
# 37                 VNQI              VANGUARD GLOBAL EX US REAL ESTATE ETF
# 38                  SLV                           IHARE SILVERS TR ISHARES
# 39                  VWO                               VANGUARD INTL EQUITY
# 40               HASH11                       HASHDEX NASDAQ CRYPTO INDEX
#
#                                Nome da Fonte Pagadora  CNPJ Desorganizado  \
# 0                                 BANCO DO BRASIL S.A        1.910000e+02
# 1                                          WEG S.A .G        8.442970e+13
# 2                                          FLEURY S.A        6.084006e+13
# 3                                            AMBEV S.        7.526557e+12
# 4                         CIA DE SANEAMENTO DO PARANA        7.648401e+13
# 5                   TRANSMIS. ALIANCA ENERG. ELETRICA        7.859971e+12
# 6                                    PORTO SEGURO S.A        2.149205e+12
# 7                                  MAGAZINE LUIZA S.A        4.796095e+13
# 8                                    LOJAS RENNER S.A        9.275474e+13
# 9                                          ITAUSA S.A        6.153264e+13
# 10                                         ITAUSA S.A        6.153264e+13
# 11                           ENGIE BRASIL ENERGIA S.A        2.474103e+12
# 12                    BB SEGURIDADE PARTICIPACOES S.A        1.734460e+13
# 13                        AMERICAN TOWER CORPORATION                  NaN
# 14                          DIGITAL REALTY TRUST INC                  NaN
# 15                          ESSEX PROPERTY TRUST INC                  NaN
# 16                    NATIONAL RETAIL PROPERTIES INC                  NaN
# 17                                          PROLOGIS                  NaN
# 18                          REALTY INCOME CORPORATION                 NaN
# 19                          B3 AS BRASIL BOLSA BALCAO        9.346601e+12
# 20                                     ODONTOPREV S.A        5.811920e+13
# 21                                  AURA MINERALS INC                 NaN
# 22  VORTX DISTRIBUIDORA DE TITULOS E VALORES IMOBI...        2.650279e+13
# 23  BRL DISTRIBUIDORA DE TITULOS E VALORES MOBILIA...        2.485304e+13
# 24  BRL DISTRIBUIDORA DE TITULOS E VALORES MOBILIA...        1.251619e+13
# 25  BRL DISTRIBUIDORA DE TITULOS E VALORES MOBILIA...        1.755427e+13
# 26          BTG PACTUAL SERVICOS FINANCEIROS S.A DTVM        2.873777e+13
# 27          BTG PACTUAL SERVICOS FINANCEIROS S.A DTVM        2.883033e+13
# 28          BTG PACTUAL SERVICOS FINANCEIROS S.A DTVM        9.752123e+13
# 29                     CREDIT SUISSE HEDGING GRIFFO C        2.964123e+13
# 30                                    BANCO FATOR S/A        1.166420e+13
# 31  BRL DISTRIBUIDORA DE TITULOS E VALORES MOBILIA...        2.221934e+13
# 32          BTG PACTUAL SERVICOS FINANCEIROS S.A DTVM        1.183959e+13
# 33                                   INTRAG DTVM LTDA        1.200596e+13
# 34                       INVESCO QQQ TR UNIT SER 1 .Q                 NaN
# 35         S&P 500 DIVIDEND ARISTOCRATS PROSHARES L.B                 NaN
# 36                        GOLD TRUST (ETF) ISHARES .U                 NaN
# 37          VANGUARD GLOBAL EX US REAL ESTATE ETF I.Q                 NaN
# 38                        IHARE SILVERS TR ISHARES .V                 NaN
# 39                            VANGUARD INTL EQUITY .O                 NaN
# 40                                   BANCO GENIAL S.A        3.831471e+13
#
#     Valor Ano Anterior  Valor Atual CNPJ Fonte Pagadora      CNPJ Formatado  \
# 0               896.14      1215.55  00.000.000/0001-91  00.000.000/0001-91
# 1              1374.24      2849.74  84.429.695/0001-11  84.429.695/0001-11
# 2              1478.87      1735.44  60.840.055/0001-31  60.840.055/0001-31
# 3               914.72      1495.56  07.526.557/0001-00  07.526.557/0001-00
# 4              1386.13      1896.30  76.484.013/0001-45  76.484.013/0001-45
# 5              1127.42      2849.74  07.859.971/0001-30  07.859.971/0001-30
# 6              1680.62      2477.05  02.149.205/0001-69  02.149.205/0001-69
# 7              1994.12       386.34  47.960.950/0001-21  47.960.950/0001-21
# 8              1934.72      1843.20  92.754.738/0001-62  92.754.738/0001-69
# 9                 0.00      1787.10  61.532.644/0001-15  61.532.644/0001-15
# 10                0.00       373.80  61.532.644/0001-15  61.532.644/0001-15
# 11             1273.31      1818.24  02.474.103/0001-19  02.474.103/0001-19
# 12             1191.69      2528.25  17.344.597/0001-94  17.344.597/0001-94
# 13             1686.29      2485.63                 NaN  00.000.000/0000-00
# 14             1774.93      2484.04                 NaN  00.000.000/0000-00
# 15             1706.86      2198.83                 NaN  00.000.000/0000-00
# 16             2230.23      3102.31                 NaN  00.000.000/0000-00
# 17             1377.56      2693.52                 NaN  00.000.000/0000-00
# 18                0.00      1723.74                 NaN  00.000.000/0000-00
# 19              635.96      1122.85  09.346.601/0001-25  09.346.601/0001-25
# 20              894.24      1453.83  58.119.199/0001-51  58.119.199/0001-51
# 21             2686.99      3120.00  07.857.093/0001-14  00.000.000/0000-00
# 22             3501.64      5647.56  22.610.500/0001-88  26.502.794/0001-85
# 23             3423.78      5995.80  13.486.793/0001-42  24.853.044/0001-22
# 24             4089.40      4855.20  13.486.793/0001-42  12.516.185/0001-70
# 25             1561.25         0.00  13.486.793/0001-42  17.554.274/0001-25
# 26             3634.62      5994.54  59.281.253/0001-23  28.737.771/0001-85
# 27             1390.29      5541.00  59.281.253/0001-23  28.830.325/0001-10
# 28              635.21      1089.72  59.281.253/0001-23  97.521.225/0001-25
# 29             3710.67      5987.31  61.809.182/0001-30  29.641.226/0001-53
# 30             3751.50      5510.56  33.644.196/0001-06  11.664.201/0001-00
# 31             3817.10      5432.67  13.486.793/0001-42  22.219.335/0001-38
# 32             3944.94      5823.20  59.281.253/0001-23  11.839.593/0001-09
# 33                0.00      6589.40  62.418.140/0001-31  12.005.956/0001-65
# 34             2379.65      3837.44                 NaN  00.000.000/0000-00
# 35             2571.59      3769.22                 NaN  00.000.000/0000-00
# 36             1756.20      1805.37                 NaN  00.000.000/0000-00
# 37             1756.20      1805.37                 NaN  00.000.000/0000-00
# 38             1116.89      1985.39                 NaN  00.000.000/0000-00
# 39             1430.26      2479.99                 NaN  00.000.000/0000-00
# 40             1603.00      1325.85  38.314.708/0001-90  38.314.708/0001-90
#
#     Grupo  Código            País inicio_ticket
# 0       3       1          Brasil          BBAS
# 1       3       1          Brasil          WEGE
# 2       3       1          Brasil          FLRY
# 3       3       1          Brasil          ABEV
# 4       3       1          Brasil          SAPR
# 5       3       1          Brasil          TAEE
# 6       3       1          Brasil          PSSA
# 7       3       1          Brasil          MGLU
# 8       3       1          Brasil          LREN
# 9       3       1          Brasil          ITSA
# 10      3       1          Brasil          ITSA
# 11      3       1          Brasil          EGIE
# 12      3       1          Brasil          BBSE
# 13      3       1  Estados Unidos            AM
# 14      3       1  Estados Unidos            DL
# 15      3       1  Estados Unidos            ES
# 16      3       1  Estados Unidos            NN
# 17      3       1  Estados Unidos            PL
# 18      3       1  Estados Unidos
# 19      3       1          Brasil          B3SA
# 20      3       1          Brasil          ODPV
# 21      4       4          Brasil         AURA3
# 22      7       3          Brasil          XPLG
# 23      7       3          Brasil          VILG
# 24      7       3          Brasil          VINO
# 25      7       3          Brasil          VISC
# 26      7       3          Brasil          ALZR
# 27      7       3          Brasil          IRDM
# 28      7       3          Brasil          MXRF
# 29      7       3          Brasil          HGRU
# 30      7       3          Brasil          VRTA
# 31      7       3          Brasil          BCRI
# 32      7       3          Brasil          BTLG
# 33      7       3          Brasil          KNRI
# 34      7       9  Estados Unidos            QQ
# 35      7       9  Estados Unidos           NOB
# 36      7       9  Estados Unidos            IA
# 37      7       9  Estados Unidos           VNQ
# 38      7       9  Estados Unidos            SL
# 39      7       9  Estados Unidos            VW
# 40      7       9          Brasil          HASH

# %% [markdown]
# # Tratando planilha de Negociações

# %%
base_negociacao_df = pd.read_excel(r"C:\Users\guilh\GitHub\automatizar_IR\Negociação.xlsx")
base_negociacao_df = base_negociacao_df.drop(["Mercado", "Prazo/Vencimento", "Instituição"], axis=1)

# Criando dataframes para filtrar os Tipo de Movimentação e  retirando o F dos códigos que terminam com ele
base_negociacao_df_compras = base_negociacao_df.loc[base_negociacao_df["Tipo de Movimentação"] == "Compra"]
base_negociacao_df_vendas = base_negociacao_df.loc[base_negociacao_df["Tipo de Movimentação"] == "Venda"]
base_negociacao_df.loc[base_negociacao_df["Código de Negociação"].str.endswith('F'), "Código de Negociação"] = base_negociacao_df["Código de Negociação"].str.rstrip('F')

#Criando um dataframe apenas para vendas e outro para compras
compras_df = pd.DataFrame(columns=["Código de Negociação", "Valor", "Quantidade"])
vendas_df = pd.DataFrame(columns=["Código de Negociação", "Valor", "Quantidade"])

compras_df = pd.concat([compras_df, base_negociacao_df_compras])
vendas_df = pd.concat([vendas_df, base_negociacao_df_vendas])

#Agrupando por Código de Negociação e somando os respectivos valores totais
compras_df = compras_df.groupby("Código de Negociação").agg({'Valor': 'sum'}).reset_index()
vendas_df = vendas_df.groupby("Código de Negociação").agg({'Valor': 'sum'}).reset_index()

vendas_df.loc[vendas_df["Código de Negociação"].str.endswith('F'), "Código de Negociação"] = vendas_df["Código de Negociação"].str.rstrip('F')
compras_df.loc[compras_df["Código de Negociação"].str.endswith('F'), "Código de Negociação"] = compras_df["Código de Negociação"].str.rstrip('F')

# Combinando os DataFrames de compras e vendas em um único DataFrame usando merge
resultado_df = pd.merge(compras_df, vendas_df, on="Código de Negociação", suffixes=("_compra", "_venda"), how="left")
# Preenchendo os valores ausentes (NaN) em "Valor_venda" com 0
resultado_df["Valor_venda"].fillna(0, inplace=True)


#Localizando o primeiro 1 e criando uma coluna para apenas as letras do código
for linha in resultado_df.index:
    posicao_1 = resultado_df.loc[linha, "Código de Negociação"].find("1")
    if posicao_1 != -1:
        if posicao_1 >= 1 and resultado_df.loc[linha, "Código de Negociação"][posicao_1 - 3] == "1":
            resultado_df.loc[linha, "inicio_ticket"] = resultado_df.loc[linha, "Código de Negociação"][:posicao_1 - 2]
        else:
            resultado_df.loc[linha, "inicio_ticket"] = resultado_df.loc[linha, "Código de Negociação"][:posicao_1]
    else:
         resultado_df.loc[linha, "inicio_ticket"] = resultado_df.loc[linha, "Código de Negociação"][:-1]

resultado_df = resultado_df.groupby(["inicio_ticket"]).agg({'Valor_compra': 'sum', 'Valor_venda': 'sum'}).reset_index()

# %% [markdown]
# # Tratando planilha de Posições dos Ativos

# %%
posicao_ativos_df = pd.read_excel(r"C:\Users\guilh\GitHub\automatizar_IR\Relatorio Consolidado.xlsx", sheet_name = [0,1,2,3,4])
posicao_ativos_df = pd.concat(posicao_ativos_df.values(), ignore_index=True) 
posicao_ativos_df = posicao_ativos_df.drop(["Modalidade","Quantidade Disponível", "Administrador", "Instituição", "Conta", "Código ISIN / Distribuição", "Tipo", "Escriturador", "Quantidade Indisponível", "Motivo", "Natureza", "Número de Contrato", "OPA", "Liquidação antecipada", "Taxa", "Comissão", "Data de registro", "Data de vencimento"], axis =1)

#Localizando a posição do hifem e criando a coluna para as letras dos códigos
for linha in posicao_ativos_df.index:
    posicao_hifem = posicao_ativos_df.loc[linha, "Produto"].find("-")
    if posicao_hifem != -1:
        posicao_ativos_df.loc[linha, "Razão Social"] = posicao_ativos_df.loc[linha, "Produto"][posicao_hifem + 1:].strip()
        if posicao_hifem >= 1 and posicao_ativos_df.loc[linha, "Produto"][posicao_hifem - 2] == "1":
            posicao_ativos_df.loc[linha, "inicio_ticket"] = posicao_ativos_df.loc[linha, "Produto"][:posicao_hifem - 3]
        else:
            posicao_ativos_df.loc[linha, "inicio_ticket"] = posicao_ativos_df.loc[linha, "Produto"][:posicao_hifem - 2]

razao_social = pd.DataFrame(posicao_ativos_df[["Razão Social", "inicio_ticket"]])
           
#Agrupando os ativos que possuem mesma letra         
posicao_ativos_df = posicao_ativos_df.groupby(["inicio_ticket"]).agg({'Quantidade': 'sum', 'Valor Atualizado': 'sum'}).reset_index()

#Em caso de duplicação da coluna quantidade, remove -las
columns_to_remove = ["Quantidade_x", "Quantidade_y"]
for col in columns_to_remove:
    if col in resultado_df.columns:
        resultado_df = resultado_df.drop(col, axis=1)



#Passando a coluna quantidade da posição atual para resultado
resultado_df = resultado_df.merge(posicao_ativos_df[["inicio_ticket", "Quantidade"]], on="inicio_ticket", how="left")

# Calculando o "Preço Médio" diretamente no DataFrame resultante

resultado_df["Preço Médio"] = (resultado_df["Valor_compra"] - resultado_df["Valor_venda"]) / (resultado_df["Quantidade"])

#Juntando o Preço Médio no dataframe de Posição dos Ativos
posicao_ativos_df = posicao_ativos_df.merge(resultado_df[["inicio_ticket", "Preço Médio"]], on = "inicio_ticket", how = "inner")
posicao_ativos_df = posicao_ativos_df.merge(razao_social[["inicio_ticket", "Razão Social"]], on = "inicio_ticket", how = "inner")

posicao_ativos_df = posicao_ativos_df.drop_duplicates(subset=["inicio_ticket"])
# Out:
#    inicio_ticket  Quantidade  Valor Atualizado  Preço Médio  \
# 0           ABEV         103           1495.56    14.556117
# 1           ALZR          54           5994.54   109.834444
# 2          AURA3         104           3120.00    48.062788
# 3           B3SA          85           1122.85    12.194353
# 4           BBAS          35           1215.55    32.091143
# 5           BBSE          75           2528.25    22.847467
# 6           BCRI          57           5432.67   108.752807
# 7           BTLG          58           5823.20   105.202931
# 8           EGIE          48           1818.24    40.482292
# 9           FLRY         110           1735.44    20.169182
# 11          HASH          87           1352.85    32.367931
# 12          HGRU          49           5987.31   115.313673
# 13          IRDM          60           5541.00    75.684667
# 14          ITSA         252           2160.90     8.936786
# 16          KNRI          47           6589.40   132.396596
# 17          LREN          90           1843.20    28.923111
# 18          MGLU         141            386.34    13.036241
# 19          MXRF         108           1089.72     9.293241
# 20          ODPV         161           1453.83    11.107950
# 21          PSSA         107           2477.05    21.891495
# 22          SAPR         105           1896.30    20.547333
# 23          TAEE          60           2080.20    36.295500
# 24          VILG          60           5995.80    96.474833
# 25          VINO         102           4855.20    55.448725
# 26          VRTA          62           5510.56    93.008065
# 27          WEGE          74           2849.74    32.682432
# 28          XPLG          57           5647.56    97.037719
#
#                                          Razão Social
# 0                                          AMBEV S.A.
# 1        ALIANZA TRUST RENDA IMOBILIARIA FDO INV IMOB
# 2                                  AURA MINERALS INC.
# 3                     B3 S.A. - BRASIL, BOLSA, BALCÃO
# 4                                     BCO BRASIL S.A.
# 5                    BB SEGURIDADE PARTICIPAÇÕES S.A.
# 6   BANESTES RECEBÍVEIS IMOBILIÁRIOS FDO INV IMOB ...
# 7            BTG PACTUAL LOGISTICA FDO INV IMOB - FII
# 8                           ENGIE BRASIL ENERGIA S.A.
# 9                                         FLEURY S.A.
# 11        HASHDEX NASDAQ CRYPTO INDEX FUNDO DE ÍNDICE
# 12             CSHG RENDA URBANA - FDO INV IMOB - FII
# 13                FII IRIDIUM RECEBÍVEIS IMOBILIÁRIOS
# 14                                        ITAUSA S.A.
# 16         KINEA RENDA IMOBILIÁRIA FDO INV IMOB - FII
# 17                                  LOJAS RENNER S.A.
# 18                                MAGAZINE LUIZA S.A.
# 19                      MAXI RENDA FDO INV IMOB - FII
# 20                                    ODONTOPREV S.A.
# 21                                  PORTO SEGURO S.A.
# 22                 CIA SANEAMENTO DO PARANA - SANEPAR
# 23      TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A.
# 24                 VINCI LOGÍSTICA FDO INV IMOB - FII
# 25                         VINCI OFFICES FDO INV IMOB
# 26                    FATOR VERITA FDO INV IMOB - FII
# 27                                           WEG S.A.
# 28                          XP LOG FDO INV IMOB - FII

# %% [markdown]
# # Tratando planilha proventos recebidos (RETIRAR)

# %%
#Importando e tratando a planilha Proventos Recebidos
proventos_recebidos_df = pd.read_excel(r"C:\Users\guilh\GitHub\automatizar_IR\Proventos Recebidos.xlsx")

#Transformando a coluna de Data para formatação de data e filtrando apenas o ano vigente
proventos_recebidos_df["Pagamento"] = pd.to_datetime(proventos_recebidos_df["Pagamento"], dayfirst = True).dt.year
proventos_recebidos_df = proventos_recebidos_df.loc[proventos_recebidos_df["Pagamento"] == ano]



#Retirando o reembolso da planilha
proventos_recebidos_df = proventos_recebidos_df.loc[proventos_recebidos_df["Tipo de Evento"] != "Reembolso"]


#Localizando o hifem e criando uma coluna para apenas as letras do código
for linha in proventos_recebidos_df.index:
    posicao_hifem = proventos_recebidos_df.loc[linha, "Produto"].find(" ")
    if posicao_hifem != -1:
        if posicao_hifem >= 1 and proventos_recebidos_df.loc[linha, "Produto"][posicao_hifem - 2] == "1":
            proventos_recebidos_df.loc[linha, "inicio_ticket"] = proventos_recebidos_df.loc[linha, "Produto"][:posicao_hifem - 2]
            proventos_recebidos_df.loc[linha, "Código de Negociação"] = proventos_recebidos_df.loc[linha, "Produto"][:posicao_hifem ]
        else:
            proventos_recebidos_df.loc[linha, "inicio_ticket"] = proventos_recebidos_df.loc[linha, "Produto"][:posicao_hifem - 1]
            proventos_recebidos_df.loc[linha, "Código de Negociação"] = proventos_recebidos_df.loc[linha, "Produto"][:posicao_hifem]

#proventos_recebidos_df = proventos_recebidos_df.drop_duplicates(subset=["Código de Negociação", "Tipo de Evento"])

proventos_recebidos_df = proventos_recebidos_df.merge(base_ticket[["inicio_ticket", "CNPJ Fonte Pagadora"]] , on = "inicio_ticket", how = "inner")
#proventos_recebidos_df.to_excel("teste.xlsx")
#proventos_recebidos_df = proventos_recebidos_df.drop_duplicates(subset=["Código de Negociação", "Tipo de Evento"])

proventos_recebidos_df.to_excel("teste.xlsx")

#Agrupando os tickets e os rendimentos


proventos_recebidos_df =  proventos_recebidos_df.groupby(["inicio_ticket", "Tipo de Evento"]).agg({'Valor líquido': 'sum'}).reset_index()

display(proventos_recebidos_df)

#Retirando os valores duplicados
proventos_recebidos_df = proventos_recebidos_df.drop_duplicates(subset=["CNPJ Fonte Pagadora", "Tipo de Evento"])

proventos_recebidos_df = proventos_recebidos_df.merge(base_ticket[["CNPJ Fonte Pagadora", "Nome da Fonte Pagadora"]] , on = "CNPJ Fonte Pagadora", how = "inner")
proventos_recebidos_df = proventos_recebidos_df.drop_duplicates(subset=["CNPJ Fonte Pagadora", "Tipo de Evento"])

#Agrupando pelas empresas pagadoras
#proventos_recebidos_df = proventos_recebidos_df.groupby(["Nome da Fonte Pagadora", "Tipo de Evento"]).agg({'Valor líquido': 'sum'}).reset_index()

#proventos_recebidos_df = proventos_recebidos_df.merge(base_ticket[["inicio_ticket", "CNPJ Fonte Pagadora"]] , on = "inicio_ticket", how = "inner")


#Criando uma coluna para Tipo de Rendimento e Tipo para cada rendimento
proventos_recebidos_df.loc[proventos_recebidos_df["Tipo de Evento"] == "Juros Sobre Capital Próprio", "Tipo de Rendimento"] = "10"
proventos_recebidos_df.loc[proventos_recebidos_df["Tipo de Evento"] != "Juros Sobre Capital Próprio", "Tipo de Rendimento"] = "09"
proventos_recebidos_df.loc[proventos_recebidos_df["Tipo de Evento"] == "Juros Sobre Capital Próprio", "Tipo"] = "Rend. Sujeitos A Trib. Exclusiva"
proventos_recebidos_df.loc[proventos_recebidos_df["Tipo de Evento"] != "Juros Sobre Capital Próprio", "Tipo"] = "Rend. Isentos e Não Trib."

display(proventos_recebidos_df)
# Out:
#    inicio_ticket               Tipo de Evento  Valor líquido
# 0           ABEV  Juros Sobre Capital Próprio          66.74
# 1           ALZR                   Rendimento         723.96
# 2          AURA3                    Dividendo          64.89
# 3           B3SA                    Dividendo          16.94
# 4           B3SA  Juros Sobre Capital Próprio          12.38
# 5           BBAS                    Dividendo          28.34
# 6           BBAS  Juros Sobre Capital Próprio          92.95
# 7           BBAS                   Rendimento           0.79
# 8           BBSE                    Dividendo         139.14
# 9           BBSE                   Rendimento           0.67
# 10          BCRI                   Rendimento         738.28
# 11          BTLG                   Rendimento         463.36
# 12          EGIE                    Dividendo          86.41
# 13          EGIE  Juros Sobre Capital Próprio           1.93
# 14          FLRY                    Dividendo          61.75
# 15          HGRU                   Rendimento         451.98
# 16          IRDM                   Rendimento         662.03
# 17          ITSA  Juros Sobre Capital Próprio         120.04
# 18          KNRI                   Rendimento         360.46
# 19          LREN  Juros Sobre Capital Próprio          43.32
# 20          MGLU  Juros Sobre Capital Próprio           0.40
# 21          MXRF                   Rendimento         110.21
# 22          ODPV                    Dividendo          23.92
# 23          ODPV  Juros Sobre Capital Próprio          15.52
# 24          PSSA                    Dividendo          38.02
# 25          PSSA  Juros Sobre Capital Próprio          17.07
# 26          SAPR                    Dividendo           5.63
# 27          SAPR  Juros Sobre Capital Próprio          46.41
# 28          TAEE                    Dividendo         176.80
# 29          TAEE  Juros Sobre Capital Próprio          54.92
# 30          VILG                   Rendimento         460.85
# 31          VINO                   Rendimento         386.56
# 32          VISC                   Rendimento          11.34
# 33          VRTA                   Rendimento         716.05
# 34          WEGE                    Dividendo          18.58
# 35          WEGE  Juros Sobre Capital Próprio           5.66
# 36          XPLG                   Rendimento         440.78
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[374], line 37
#      34 display(proventos_recebidos_df)
#      36 #Retirando os valores duplicados
# ---> 37 proventos_recebidos_df = proventos_recebidos_df.drop_duplicates(subset=["CNPJ Fonte Pagadora", "Tipo de Evento"])
#      39 proventos_recebidos_df = proventos_recebidos_df.merge(base_ticket[["CNPJ Fonte Pagadora", "Nome da Fonte Pagadora"]] , on = "CNPJ Fonte Pagadora", how = "inner")
#      40 proventos_recebidos_df = proventos_recebidos_df.drop_duplicates(subset=["CNPJ Fonte Pagadora", "Tipo de Evento"])
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:6672, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6670 inplace = validate_bool_kwarg(inplace, "inplace")
#    6671 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6672 duplicated = self.duplicated(subset, keep=keep)
#    6674 result = self[-duplicated]
#    6675 if ignore_index:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:6806, in DataFrame.duplicated(self, subset, keep)
#    6804 diff = set(subset) - set(self.columns)
#    6805 if diff:
# -> 6806     raise KeyError(Index(diff))
#    6808 if len(subset) == 1 and self.columns.is_unique:
#    6809     # GH#45236 This is faster than get_group_index below
#    6810     result = self[subset[0]].duplicated(keep)
#
# KeyError: Index(['CNPJ Fonte Pagadora'], dtype='object')

# %% [markdown]
# # Rendimentos Isentos e Não Tributavéis

# %%
pyautogui.FAILSAFE = True
pyautogui.PAUSE = 0.5


imagem = encontrar_imagem(r"C:\Users\guilh\GitHub\automatizar_IR\rend_isentos.png")
pyautogui.click(pyautogui.center(imagem))

#Preenchendo para os rendimentos de renda fixa
for linha in rend_isentos.index:
    imagem = encontrar_imagem(r"C:\Users\guilh\GitHub\automatizar_IR\botao_novo.png")
    pyautogui.click(pyautogui.center(imagem))
    tipo = rend_isentos.loc[linha , "Tipo de Rendimento"]
    CNPJ = rend_isentos.loc[linha, "CNPJ Desorganizado"]
    nome = rend_isentos.loc[linha, "Nome da Fonte Pagadora"]
    valor = rend_isentos.loc[linha, "Valor"]
    valor = converter_num_Brasil(str(valor))
    pyautogui.write(str(tipo))
    pyautogui.press("enter")
    pyautogui.click(x=631, y=611)
    pyautogui.write(str(CNPJ))
    pyautogui.press("tab")
    pyautogui.write(str(nome))
    pyautogui.press("tab")
    pyautogui.write(str(valor))     
    imagem = encontrar_imagem(r"C:\Users\guilh\GitHub\automatizar_IR\botao_ok.png")
    pyautogui.click(pyautogui.center(imagem))
    
#Preenchendo para os dividendos e rendimentos

imagem = encontrar_imagem(r"C:\Users\guilh\GitHub\automatizar_IR\rend_isentos.png")
pyautogui.click(pyautogui.center(imagem))

for linha in proventos_recebidos_df.index:
    tipo = proventos_recebidos_df.loc[linha, "Tipo de Rendimento"]
    CNPJ = proventos_recebidos_df.loc[linha, "CNPJ Fonte Pagadora"]
    nome = proventos_recebidos_df.loc[linha, "Nome da Fonte Pagadora"]
    valor = proventos_recebidos_df.loc[linha, "Valor líquido"]
    valor = converter_num_Brasil(str(valor))
    if tipo != "09":
        pass
    else :
        imagem = encontrar_imagem(r"C:\Users\guilh\GitHub\automatizar_IR\botao_novo.png")
        pyautogui.click(pyautogui.center(imagem))
        pyautogui.write(str(tipo))
        pyautogui.press("enter")
        pyautogui.click(x=605, y=586)
        pyautogui.write(copiar_colar(CNPJ))
        pyautogui.press("tab")
        pyautogui.write(str(nome))
        pyautogui.press("tab")
        pyautogui.write(str(valor))     
        imagem = encontrar_imagem(r"C:\Users\guilh\GitHub\automatizar_IR\botao_ok.png")
        pyautogui.click(pyautogui.center(imagem))
            360,46000000000004
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[314], line 45
#      43 pyautogui.click(pyautogui.center(imagem))
#      44 pyautogui.write(str(tipo))
# ---> 45 pyautogui.press("enter")
#      46 pyautogui.click(x=605, y=586)
#      47 pyautogui.write(copiar_colar(CNPJ))
#
# File ~\anaconda3\Lib\site-packages\pyautogui\__init__.py:595, in _genericPyAutoGUIChecks.<locals>.wrapper(*args, **kwargs)
#     593 failSafeCheck()
#     594 returnVal = wrappedFunction(*args, **kwargs)
# --> 595 _handlePause(kwargs.get("_pause", True))
#     596 return returnVal
#
# File ~\anaconda3\Lib\site-packages\pyautogui\__init__.py:639, in _handlePause(_pause)
#     637 if _pause:
#     638     assert isinstance(PAUSE, int) or isinstance(PAUSE, float)
# --> 639     time.sleep(PAUSE)
#
# KeyboardInterrupt:

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[89], line 20
#      18 imagem = encontrar_imagem(r"C:\Users\guilh\GitHub\automatizar_IR\botao_novo.png")
#      19 pyautogui.click(pyautogui.center(imagem))
# ---> 20 pyautogui.write(str(tipo))
#      21 pyautogui.press("enter")
#      22 pyautogui.click(x=605, y=586)
#
# File ~\anaconda3\Lib\site-packages\pyautogui\__init__.py:595, in _genericPyAutoGUIChecks.<locals>.wrapper(*args, **kwargs)
#     593 failSafeCheck()
#     594 returnVal = wrappedFunction(*args, **kwargs)
# --> 595 _handlePause(kwargs.get("_pause", True))
#     596 return returnVal
#
# File ~\anaconda3\Lib\site-packages\pyautogui\__init__.py:639, in _handlePause(_pause)
#     637 if _pause:
#     638     assert isinstance(PAUSE, int) or isinstance(PAUSE, float)
# --> 639     time.sleep(PAUSE)
#
# KeyboardInterrupt:

# %%
print(pyautogui.position())
# Out:
# Point(x=605, y=586)
